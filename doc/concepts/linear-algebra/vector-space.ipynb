# %% [markdown]
# # 向量空间
#
# 线性代数主要研究有限维向量空间上的线性映射。在线性代数中，如果将复数与实数放在一起研究，就会得到更好的定理和更深刻的见解。把平面和三维空间这些例子推广到 $\mathbb{R}^n$ 和 $\mathbb{C}^n$，再进一步推广得到向量空间的概念。
#
# 向量空间是具有满足自然的代数性质的加法和标量乘法运算的集合。

# %%
from manim import *

# %%
# %%manim -v WARNING --disable_caching -qm BannerExample
#
# config.media_width = "25%"
# # config.media_embed = True
#
# class SquareToCircle(Scene):
#     def construct(self):
#         circle = Circle()  # 创建圆
#         circle.set_fill(PINK, opacity=0.5)  # 设置颜色和透明度
#
#         square = Square()  # 创建正方形
#         square.rotate(PI / 4)  # 旋转一定角度
#
#         self.play(Create(square))  # 动画显示正方形的创建
#         self.play(Transform(square, circle))  # 将正方形插值转换为圆
#         self.play(FadeOut(square))  # 淡出动画
# Out:
# Manim Community v0.18.1
# <video controls autoplay loop style="max-width: 75%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
