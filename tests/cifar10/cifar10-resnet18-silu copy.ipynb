# %% [markdown]
# # Cifar10 上的 ReNet18
#
# 本文主要介绍在 cifar10 的试验 resnet18 的性能。
#
# 导入一些必要包：

# %%
import logging
import torch
from torch import nn
from torch.profiler import profile, record_function, ProfilerActivity
from torchvision.models import resnet18, ResNet18_Weights
from torch_book.vision.classifier import Classifier, evaluate_accuracy
from torch_book.datasets.cifar10 import Cifar10
torch.cuda.empty_cache() # 清空 GPU 缓存


logging.basicConfig(filename='logs/debug-graph.log',
                    filemode="w",
                    format='%(asctime)s|%(levelname)s|%(name)s->%(funcName)s@%(message)s',
                    level=logging.INFO)

# %%
import torch_book
print(torch_book.__version__)
# Out:
# 0.0.10

# %% [markdown]
# {mod}`torchvision` 上的 ResNet18 直接用于 cifar10 是不推荐的。需要做以下改动：

# %% [markdown]
# ```{note}
# 将 `conv1` 替换以支持 $32 \times 32$ 的输入。同时移除第一个 `maxpool` 避免图片信息过早丢失。
# ```

# %%
model = resnet18(weights=ResNet18_Weights.DEFAULT)
model.conv1 = nn.Conv2d(model.conv1.in_channels, 
                        model.conv1.out_channels,
                        3, 1, 1, bias=False)
model.maxpool = nn.Identity()
model.fc = nn.Linear(model.fc.in_features, 10)

# %% [markdown]
# ## 模块变换
#
# 利用 FX 替换全部 {class}`~torch.nn.ReLU` 为 {func}`torch.nn.SiLU`。

# %%
import torch
from torch import fx, nn
from torch.nn import functional as F
def replace(model):
    mod = fx.symbolic_trace(model)
    # 遍历 Graph 中全部节点
    for node in mod.graph.nodes:
        # 如果匹配目标
        if node.op == "call_module":
            if "relu" in node.target:
                # 设置插入点，添加新节点，用新节点替换所有 `node` 的用法
                with mod.graph.inserting_after(node):
                    new_node = mod.graph.call_function(F.silu, node.args, node.kwargs)
                    node.replace_all_uses_with(new_node)
                # 移除 graph 中旧的节点
                mod.graph.erase_node(node)
    mod.graph.lint()
    # 不用忘记 recompile！
    new_code = mod.recompile()
    return mod

# %%
model = replace(model)

# %%
model.graph.print_tabular()
# Out:
# opcode         name                   target                                                      args                                   kwargs
# -------------  ---------------------  ----------------------------------------------------------  -------------------------------------  --------
# placeholder    x                      x                                                           ()                                     {}
# call_module    conv1                  conv1                                                       (x,)                                   {}
# call_module    bn1                    bn1                                                         (conv1,)                               {}
# call_function  silu                   <function silu at 0x7fb76b4d4f70>                           (bn1,)                                 {}
# call_module    maxpool                maxpool                                                     (silu,)                                {}
# call_module    layer1_0_conv1         layer1.0.conv1                                              (maxpool,)                             {}
# call_module    layer1_0_bn1           layer1.0.bn1                                                (layer1_0_conv1,)                      {}
# call_function  silu_1                 <function silu at 0x7fb76b4d4f70>                           (layer1_0_bn1,)                        {}
# call_module    layer1_0_conv2         layer1.0.conv2                                              (silu_1,)                              {}
# call_module    layer1_0_bn2           layer1.0.bn2                                                (layer1_0_conv2,)                      {}
# call_function  add                    <built-in function add>                                     (layer1_0_bn2, maxpool)                {}
# call_function  silu_2                 <function silu at 0x7fb76b4d4f70>                           (add,)                                 {}
# call_module    layer1_1_conv1         layer1.1.conv1                                              (silu_2,)                              {}
# call_module    layer1_1_bn1           layer1.1.bn1                                                (layer1_1_conv1,)                      {}
# call_function  silu_3                 <function silu at 0x7fb76b4d4f70>                           (layer1_1_bn1,)                        {}
# call_module    layer1_1_conv2         layer1.1.conv2                                              (silu_3,)                              {}
# call_module    layer1_1_bn2           layer1.1.bn2                                                (layer1_1_conv2,)                      {}
# call_function  add_1                  <built-in function add>                                     (layer1_1_bn2, silu_2)                 {}
# call_function  silu_4                 <function silu at 0x7fb76b4d4f70>                           (add_1,)                               {}
# call_module    layer2_0_conv1         layer2.0.conv1                                              (silu_4,)                              {}
# call_module    layer2_0_bn1           layer2.0.bn1                                                (layer2_0_conv1,)                      {}
# call_function  silu_5                 <function silu at 0x7fb76b4d4f70>                           (layer2_0_bn1,)                        {}
# call_module    layer2_0_conv2         layer2.0.conv2                                              (silu_5,)                              {}
# call_module    layer2_0_bn2           layer2.0.bn2                                                (layer2_0_conv2,)                      {}
# call_module    layer2_0_downsample_0  layer2.0.downsample.0                                       (silu_4,)                              {}
# call_module    layer2_0_downsample_1  layer2.0.downsample.1                                       (layer2_0_downsample_0,)               {}
# call_function  add_2                  <built-in function add>                                     (layer2_0_bn2, layer2_0_downsample_1)  {}
# call_function  silu_6                 <function silu at 0x7fb76b4d4f70>                           (add_2,)                               {}
# call_module    layer2_1_conv1         layer2.1.conv1                                              (silu_6,)                              {}
# call_module    layer2_1_bn1           layer2.1.bn1                                                (layer2_1_conv1,)                      {}
# call_function  silu_7                 <function silu at 0x7fb76b4d4f70>                           (layer2_1_bn1,)                        {}
# call_module    layer2_1_conv2         layer2.1.conv2                                              (silu_7,)                              {}
# call_module    layer2_1_bn2           layer2.1.bn2                                                (layer2_1_conv2,)                      {}
# call_function  add_3                  <built-in function add>                                     (layer2_1_bn2, silu_6)                 {}
# call_function  silu_8                 <function silu at 0x7fb76b4d4f70>                           (add_3,)                               {}
# call_module    layer3_0_conv1         layer3.0.conv1                                              (silu_8,)                              {}
# call_module    layer3_0_bn1           layer3.0.bn1                                                (layer3_0_conv1,)                      {}
# call_function  silu_9                 <function silu at 0x7fb76b4d4f70>                           (layer3_0_bn1,)                        {}
# call_module    layer3_0_conv2         layer3.0.conv2                                              (silu_9,)                              {}
# call_module    layer3_0_bn2           layer3.0.bn2                                                (layer3_0_conv2,)                      {}
# call_module    layer3_0_downsample_0  layer3.0.downsample.0                                       (silu_8,)                              {}
# call_module    layer3_0_downsample_1  layer3.0.downsample.1                                       (layer3_0_downsample_0,)               {}
# call_function  add_4                  <built-in function add>                                     (layer3_0_bn2, layer3_0_downsample_1)  {}
# call_function  silu_10                <function silu at 0x7fb76b4d4f70>                           (add_4,)                               {}
# call_module    layer3_1_conv1         layer3.1.conv1                                              (silu_10,)                             {}
# call_module    layer3_1_bn1           layer3.1.bn1                                                (layer3_1_conv1,)                      {}
# call_function  silu_11                <function silu at 0x7fb76b4d4f70>                           (layer3_1_bn1,)                        {}
# call_module    layer3_1_conv2         layer3.1.conv2                                              (silu_11,)                             {}
# call_module    layer3_1_bn2           layer3.1.bn2                                                (layer3_1_conv2,)                      {}
# call_function  add_5                  <built-in function add>                                     (layer3_1_bn2, silu_10)                {}
# call_function  silu_12                <function silu at 0x7fb76b4d4f70>                           (add_5,)                               {}
# call_module    layer4_0_conv1         layer4.0.conv1                                              (silu_12,)                             {}
# call_module    layer4_0_bn1           layer4.0.bn1                                                (layer4_0_conv1,)                      {}
# call_function  silu_13                <function silu at 0x7fb76b4d4f70>                           (layer4_0_bn1,)                        {}
# call_module    layer4_0_conv2         layer4.0.conv2                                              (silu_13,)                             {}
# call_module    layer4_0_bn2           layer4.0.bn2                                                (layer4_0_conv2,)                      {}
# call_module    layer4_0_downsample_0  layer4.0.downsample.0                                       (silu_12,)                             {}
# call_module    layer4_0_downsample_1  layer4.0.downsample.1                                       (layer4_0_downsample_0,)               {}
# call_function  add_6                  <built-in function add>                                     (layer4_0_bn2, layer4_0_downsample_1)  {}
# call_function  silu_14                <function silu at 0x7fb76b4d4f70>                           (add_6,)                               {}
# call_module    layer4_1_conv1         layer4.1.conv1                                              (silu_14,)                             {}
# call_module    layer4_1_bn1           layer4.1.bn1                                                (layer4_1_conv1,)                      {}
# call_function  silu_15                <function silu at 0x7fb76b4d4f70>                           (layer4_1_bn1,)                        {}
# call_module    layer4_1_conv2         layer4.1.conv2                                              (silu_15,)                             {}
# call_module    layer4_1_bn2           layer4.1.bn2                                                (layer4_1_conv2,)                      {}
# call_function  add_7                  <built-in function add>                                     (layer4_1_bn2, silu_14)                {}
# call_function  silu_16                <function silu at 0x7fb76b4d4f70>                           (add_7,)                               {}
# call_module    avgpool                avgpool                                                     (silu_16,)                             {}
# call_function  flatten                <built-in method flatten of type object at 0x7fb84f614a40>  (avgpool, 1)                           {}
# call_module    fc                     fc                                                          (flatten,)                             {}
# output         output                 output                                                      (fc,)                                  {}

# %% [markdown]
# 加载数据集：

# %%
data = Cifar10(batch_size = 128, num_workers=8, cutout=None)
train_iter = data.train_loader()
test_iter = data.val_loader()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# 做一些准备工作：

# %%
classifier = Classifier(model, train_iter, test_iter, device=torch.device("cuda:0"))
classifier.prepare_optimizer(lr=0.0142857, momentum=0.857142,
                             weight_decay=0.000857142)
classifier.prepare_scheduler(lr_period=2, lr_decay=0.857142)

# %% [markdown]
# 训练模型：

# %%
torch._dynamo.reset()
num_epochs = 60
classifier.prepare_animator(num_epochs)
classifier.fit(num_epochs)

# %%
test_acc = evaluate_accuracy(classifier.mod, classifier.test_iter, device=torch.device("cuda:0"))
test_acc
# Out:
# 0.9387

# %% [markdown]
# 保存模型（也可以直接 {download}`下载训练权重 <https://github.com/xinetzone/torch-book/releases/download/resnet18_cifar10_relu/resnet18_cifar10_relu.h5>`）：

# %%
torch.save(classifier.mod.state_dict(),
           'params/resnet18_cifar10_silu.h5')

# %% [markdown]
# ## Cutout Cifar10 训练

# %%
import logging
import torch
from torch import nn
from torch.profiler import profile, record_function, ProfilerActivity
from torchvision.models import resnet18, ResNet18_Weights
from torch_book.vision.classifier import Classifier, evaluate_accuracy
from torch_book.datasets.cifar10 import Cifar10
torch.cuda.empty_cache() # 清空 GPU 缓存
from torch_book.transforms.cutout import Cutout


logging.basicConfig(filename='logs/debug-graph.log',
                    filemode="a",
                    format='%(asctime)s|%(levelname)s|%(name)s->%(funcName)s@%(message)s',
                    level=logging.INFO)

num_epochs = 100
model = resnet18(weights=ResNet18_Weights.DEFAULT)
model.conv1 = nn.Conv2d(model.conv1.in_channels,
                        model.conv1.out_channels,
                        3, 1, 1, bias=False)
model.maxpool = nn.Identity()
model.fc = nn.Linear(model.fc.in_features, 10)
model = replace(model)
data = Cifar10(batch_size = 64, cutout=Cutout(1, 16), num_workers=8)
train_iter = data.train_loader()
test_iter = data.val_loader()
classifier = Classifier(model, train_iter, test_iter, device=torch.device("cuda:0"))
classifier.prepare_optimizer(lr=0.0142857, momentum=0.857142,
                             weight_decay=0.000857142)
classifier.prepare_scheduler(lr_period=2, lr_decay=0.857142)
classifier.prepare_animator(num_epochs)
classifier.fit(num_epochs)

# %%
test_acc = evaluate_accuracy(classifier.mod, classifier.test_iter, device=torch.device("cuda:0"))
test_acc
# Out:
# 0.9485

# %%
classifier.mod.graph.print_tabular()
# Out:
# opcode         name                   target                                                      args                                   kwargs
# -------------  ---------------------  ----------------------------------------------------------  -------------------------------------  --------
# placeholder    x                      x                                                           ()                                     {}
# call_module    conv1                  conv1                                                       (x,)                                   {}
# call_module    bn1                    bn1                                                         (conv1,)                               {}
# call_function  silu                   <function silu at 0x7fb76b4d4f70>                           (bn1,)                                 {}
# call_module    maxpool                maxpool                                                     (silu,)                                {}
# call_module    layer1_0_conv1         layer1.0.conv1                                              (maxpool,)                             {}
# call_module    layer1_0_bn1           layer1.0.bn1                                                (layer1_0_conv1,)                      {}
# call_function  silu_1                 <function silu at 0x7fb76b4d4f70>                           (layer1_0_bn1,)                        {}
# call_module    layer1_0_conv2         layer1.0.conv2                                              (silu_1,)                              {}
# call_module    layer1_0_bn2           layer1.0.bn2                                                (layer1_0_conv2,)                      {}
# call_function  add                    <built-in function add>                                     (layer1_0_bn2, maxpool)                {}
# call_function  silu_2                 <function silu at 0x7fb76b4d4f70>                           (add,)                                 {}
# call_module    layer1_1_conv1         layer1.1.conv1                                              (silu_2,)                              {}
# call_module    layer1_1_bn1           layer1.1.bn1                                                (layer1_1_conv1,)                      {}
# call_function  silu_3                 <function silu at 0x7fb76b4d4f70>                           (layer1_1_bn1,)                        {}
# call_module    layer1_1_conv2         layer1.1.conv2                                              (silu_3,)                              {}
# call_module    layer1_1_bn2           layer1.1.bn2                                                (layer1_1_conv2,)                      {}
# call_function  add_1                  <built-in function add>                                     (layer1_1_bn2, silu_2)                 {}
# call_function  silu_4                 <function silu at 0x7fb76b4d4f70>                           (add_1,)                               {}
# call_module    layer2_0_conv1         layer2.0.conv1                                              (silu_4,)                              {}
# call_module    layer2_0_bn1           layer2.0.bn1                                                (layer2_0_conv1,)                      {}
# call_function  silu_5                 <function silu at 0x7fb76b4d4f70>                           (layer2_0_bn1,)                        {}
# call_module    layer2_0_conv2         layer2.0.conv2                                              (silu_5,)                              {}
# call_module    layer2_0_bn2           layer2.0.bn2                                                (layer2_0_conv2,)                      {}
# call_module    layer2_0_downsample_0  layer2.0.downsample.0                                       (silu_4,)                              {}
# call_module    layer2_0_downsample_1  layer2.0.downsample.1                                       (layer2_0_downsample_0,)               {}
# call_function  add_2                  <built-in function add>                                     (layer2_0_bn2, layer2_0_downsample_1)  {}
# call_function  silu_6                 <function silu at 0x7fb76b4d4f70>                           (add_2,)                               {}
# call_module    layer2_1_conv1         layer2.1.conv1                                              (silu_6,)                              {}
# call_module    layer2_1_bn1           layer2.1.bn1                                                (layer2_1_conv1,)                      {}
# call_function  silu_7                 <function silu at 0x7fb76b4d4f70>                           (layer2_1_bn1,)                        {}
# call_module    layer2_1_conv2         layer2.1.conv2                                              (silu_7,)                              {}
# call_module    layer2_1_bn2           layer2.1.bn2                                                (layer2_1_conv2,)                      {}
# call_function  add_3                  <built-in function add>                                     (layer2_1_bn2, silu_6)                 {}
# call_function  silu_8                 <function silu at 0x7fb76b4d4f70>                           (add_3,)                               {}
# call_module    layer3_0_conv1         layer3.0.conv1                                              (silu_8,)                              {}
# call_module    layer3_0_bn1           layer3.0.bn1                                                (layer3_0_conv1,)                      {}
# call_function  silu_9                 <function silu at 0x7fb76b4d4f70>                           (layer3_0_bn1,)                        {}
# call_module    layer3_0_conv2         layer3.0.conv2                                              (silu_9,)                              {}
# call_module    layer3_0_bn2           layer3.0.bn2                                                (layer3_0_conv2,)                      {}
# call_module    layer3_0_downsample_0  layer3.0.downsample.0                                       (silu_8,)                              {}
# call_module    layer3_0_downsample_1  layer3.0.downsample.1                                       (layer3_0_downsample_0,)               {}
# call_function  add_4                  <built-in function add>                                     (layer3_0_bn2, layer3_0_downsample_1)  {}
# call_function  silu_10                <function silu at 0x7fb76b4d4f70>                           (add_4,)                               {}
# call_module    layer3_1_conv1         layer3.1.conv1                                              (silu_10,)                             {}
# call_module    layer3_1_bn1           layer3.1.bn1                                                (layer3_1_conv1,)                      {}
# call_function  silu_11                <function silu at 0x7fb76b4d4f70>                           (layer3_1_bn1,)                        {}
# call_module    layer3_1_conv2         layer3.1.conv2                                              (silu_11,)                             {}
# call_module    layer3_1_bn2           layer3.1.bn2                                                (layer3_1_conv2,)                      {}
# call_function  add_5                  <built-in function add>                                     (layer3_1_bn2, silu_10)                {}
# call_function  silu_12                <function silu at 0x7fb76b4d4f70>                           (add_5,)                               {}
# call_module    layer4_0_conv1         layer4.0.conv1                                              (silu_12,)                             {}
# call_module    layer4_0_bn1           layer4.0.bn1                                                (layer4_0_conv1,)                      {}
# call_function  silu_13                <function silu at 0x7fb76b4d4f70>                           (layer4_0_bn1,)                        {}
# call_module    layer4_0_conv2         layer4.0.conv2                                              (silu_13,)                             {}
# call_module    layer4_0_bn2           layer4.0.bn2                                                (layer4_0_conv2,)                      {}
# call_module    layer4_0_downsample_0  layer4.0.downsample.0                                       (silu_12,)                             {}
# call_module    layer4_0_downsample_1  layer4.0.downsample.1                                       (layer4_0_downsample_0,)               {}
# call_function  add_6                  <built-in function add>                                     (layer4_0_bn2, layer4_0_downsample_1)  {}
# call_function  silu_14                <function silu at 0x7fb76b4d4f70>                           (add_6,)                               {}
# call_module    layer4_1_conv1         layer4.1.conv1                                              (silu_14,)                             {}
# call_module    layer4_1_bn1           layer4.1.bn1                                                (layer4_1_conv1,)                      {}
# call_function  silu_15                <function silu at 0x7fb76b4d4f70>                           (layer4_1_bn1,)                        {}
# call_module    layer4_1_conv2         layer4.1.conv2                                              (silu_15,)                             {}
# call_module    layer4_1_bn2           layer4.1.bn2                                                (layer4_1_conv2,)                      {}
# call_function  add_7                  <built-in function add>                                     (layer4_1_bn2, silu_14)                {}
# call_function  silu_16                <function silu at 0x7fb76b4d4f70>                           (add_7,)                               {}
# call_module    avgpool                avgpool                                                     (silu_16,)                             {}
# call_function  flatten                <built-in method flatten of type object at 0x7fb84f614a40>  (avgpool, 1)                           {}
# call_module    fc                     fc                                                          (flatten,)                             {}
# output         output                 output                                                      (fc,)                                  {}

# %%
torch.save(classifier.mod.state_dict(),
           'params/resnet18_cifar10_silu_cutout.h5')

# %% [markdown]
# ## 性能度量

# %%
inputs = torch.randn(5, 3, 32, 32).type(torch.float32).cuda()       
with profile(activities=[ProfilerActivity.CPU, 
                         ProfilerActivity.CUDA], 
             record_shapes=True) as prof:
    with record_function("model_inference"):
        classifier.mod(inputs)
print(prof.key_averages().table(sort_by="cuda_time_total", row_limit=10))
# Out:
# STAGE:2023-11-20 19:47:24 2215559:2215559 ActivityProfilerController.cpp:312] Completed Stage: Warm Up
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        14.88%      35.384ms        99.98%     237.727ms     237.727ms       0.000us         0.00%       1.543ms       1.543ms             1
#                                            aten::conv2d         4.99%      11.856ms        77.42%     184.070ms       9.204ms       0.000us         0.00%       1.377ms      68.850us            20
#                                       aten::convolution         0.17%     413.000us        72.43%     172.214ms       8.611ms       0.000us         0.00%       1.377ms      68.850us            20
#                                      aten::_convolution         0.08%     194.000us        72.26%     171.801ms       8.590ms       0.000us         0.00%       1.377ms      68.850us            20
#                                 aten::cudnn_convolution        54.69%     130.025ms        72.17%     171.607ms       8.580ms     726.000us        87.36%       1.377ms      68.850us            20
#                                   cudaFuncGetAttributes         1.94%       4.605ms         1.94%       4.605ms       4.025us     640.000us        77.02%     640.000us       0.559us          1144
# void cutlass_cudnn_infer::Kernel<cutlass_tensorop_s1...         0.00%       0.000us         0.00%       0.000us       0.000us     218.000us        26.23%     218.000us      36.333us             6
# void cudnn::ops::nchwToNhwcKernel<float, float, floa...         0.00%       0.000us         0.00%       0.000us       0.000us     172.000us        20.70%     172.000us       5.375us            32
# sm86_xmma_fprop_implicit_gemm_indexed_tf32f32_tf32f3...         0.00%       0.000us         0.00%       0.000us       0.000us     130.000us        15.64%     130.000us      32.500us             4
# void cutlass_cudnn_infer::Kernel<cutlass_tensorop_s1...         0.00%       0.000us         0.00%       0.000us       0.000us     104.000us        12.52%     104.000us      26.000us             4
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 237.769ms
# Self CUDA time total: 831.000us
# STAGE:2023-11-20 19:47:25 2215559:2215559 ActivityProfilerController.cpp:318] Completed Stage: Collection
# STAGE:2023-11-20 19:47:25 2215559:2215559 ActivityProfilerController.cpp:322] Completed Stage: Post Processing

# %%
new_mod = classifier.mod.eval().cpu()

# %%
example_inputs = torch.randn(1, 3, 32, 32)

# 使用 torch.jit.trace 将模型转换为 TorchScript
traced_model = torch.jit.trace(new_mod, example_inputs)

# 保存 TorchScript 模型
torch.jit.save(traced_model, "params/resnet18_cifar10_silu_cutout.pt")
