# %% [markdown]
# # FLOPs
#
# ```{todo} 待重写
# ```
#
# 参考：[FLOPs](https://zhuanlan.zhihu.com/p/663566912?utm_psn=1701033625972346880)
#
# FLOPs（Floating Point Operations，浮点运算数）和 MACs（Multiply-Accumulate Operations，乘加运算数）是常用于计算深度学习模型计算复杂度的指标。它们是快速、简单地了解执行给定计算所需的算术运算数量的方法。例如，在为边缘设备使用不同的模型架构（如 MobileNet 或 DenseNet）时，人们使用 MACs 或 FLOPs 来估计模型性能。同时，使用“估计”这个词的原因是，这两个指标都是近似值，而不是实际运行时性能模型的捕获。然而，它们仍然可以提供有关能量消耗或计算要求的非常有用的洞察，这在边缘计算中非常有用。

# %% [markdown]
# FLOPs 特指对浮点数进行的加法、减法、乘法和除法等浮点运算的数量。这些运算在机器学习中涉及的许多数学计算中非常常见，例如矩阵乘法、激活函数和梯度计算。FLOPs 通常用于衡量模型或模型内特定操作的计算成本或复杂度。当需要提供所需算术运算总数的估计时，这非常有用，通常用于衡量计算效率的上下文中。
#
# 另一方面，MACs 只计算乘加操作的数量，这涉及将两个数字相乘并相加结果。这种运算是许多线性代数操作的基础，例如矩阵乘法、卷积和点积。在严重依赖线性代数运算的模型中，如卷积神经网络（CNN），MACs 通常用作计算复杂度的更具体度量。
#
# ```{note}
# 全大写的 FLOPS 是“每秒浮点运算数”的缩写，指的是计算速度，通常用作硬件性能的度量。FLOPS 中的“S”表示“秒”，与“P”（作为“每”）一起，通常用于表示比率。
# ```
#
#
# 一般AI社区的共识是，一个 MAC 大约等于两个 FLOP。

# %%
import torch
from torch import nn, Tensor
from torch.fx.node import Node
from tabulate import tabulate
from torch_book.scan.flop import get_FLOPs

class SimpleModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer = nn.Linear(5, 4, bias=True)
        self.__add_one = True

    def forward(self, x: Tensor):
        x = self.layer(x)
        if self.__add_one:
            x += 1.
        return x

# %%
model = SimpleModel()
gm = torch.fx.symbolic_trace(model)
sample_input = torch.randn(1, 5)

# %%
result_header = ['node_name', 'node_op', 'op_target', 'nn_module_stack[-1]', 'flops']
result_table = get_FLOPs(gm, sample_input)
__missing_values = [''] * 4 + ['ERROR']
# table_str = tabulate(result_table, result_header, tablefmt='rst', missingval=__missing_values)
table_str = tabulate(result_table, result_header, tablefmt='fancy_grid', missingval=__missing_values)
print(table_str)
valid_flops_list = list(filter(lambda _f: isinstance(_f, int), list(zip(*result_table))[-1]))
total_flops = sum(valid_flops_list)
num_empty_flops = len(result_table) - len(valid_flops_list)
print(f"total_flops = {total_flops:3,}")
# Out:
# ╒═════════════╤═══════════════╤═════════════════════════╤═══════════════════════╤═════════╕
# │ node_name   │ node_op       │ op_target               │ nn_module_stack[-1]   │   flops │
# ╞═════════════╪═══════════════╪═════════════════════════╪═══════════════════════╪═════════╡
# │ x           │ placeholder   │ x                       │                       │       0 │
# ├─────────────┼───────────────┼─────────────────────────┼───────────────────────┼─────────┤
# │ layer       │ call_module   │ layer                   │ Linear                │      40 │
# ├─────────────┼───────────────┼─────────────────────────┼───────────────────────┼─────────┤
# │ add         │ call_function │ <built-in function add> │                       │       4 │
# ├─────────────┼───────────────┼─────────────────────────┼───────────────────────┼─────────┤
# │ output      │ output        │ output                  │                       │       0 │
# ╘═════════════╧═══════════════╧═════════════════════════╧═══════════════════════╧═════════╛
# total_flops =  44

# %% [markdown]
# ## 测试 timm

# %%
import timm
vit = timm.create_model('vit_base_patch16_224').eval()
resnet = timm.create_model('resnet50').eval()

# %%
gm = torch.fx.symbolic_trace(vit)
sample_input = torch.randn([1, 3, 224, 224])
result_header = ['node_name', 'node_op', 'op_target', 'nn_module_stack[-1]', 'flops']
result_table = get_FLOPs(gm, sample_input)
__missing_values = [''] * 4 + ['ERROR']
# table_str = tabulate(result_table, result_header, tablefmt='rst', missingval=__missing_values)
table_str = tabulate(result_table, result_header, tablefmt='fancy_grid', missingval=__missing_values)
print(table_str)
valid_flops_list = list(filter(lambda _f: isinstance(_f, int), list(zip(*result_table))[-1]))
total_flops = sum(valid_flops_list)
num_empty_flops = len(result_table) - len(valid_flops_list)
print(f"total_flops = {total_flops:3,}")
# Out:
# ╒═════════════════════════════════╤═══════════════╤════════════════════════════════════════════════════════╤═══════════════════════╤════════════════╕
# │ node_name                       │ node_op       │ op_target                                              │ nn_module_stack[-1]   │ flops          │
# ╞═════════════════════════════════╪═══════════════╪════════════════════════════════════════════════════════╪═══════════════════════╪════════════════╡
# │ x                               │ placeholder   │ x                                                      │                       │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getattr_1                       │ call_function │ <built-in function getattr>                            │ PatchEmbed            │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem                         │ call_function │ <built-in function getitem>                            │ PatchEmbed            │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_1                       │ call_function │ <built-in function getitem>                            │ PatchEmbed            │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_2                       │ call_function │ <built-in function getitem>                            │ PatchEmbed            │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_3                       │ call_function │ <built-in function getitem>                            │ PatchEmbed            │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ eq                              │ call_function │ <built-in function eq>                                 │ PatchEmbed            │ 1              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ _assert                         │ call_function │ <function _assert at 0x7f5ad6f387c0>                   │ PatchEmbed            │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ eq_1                            │ call_function │ <built-in function eq>                                 │ PatchEmbed            │ 1              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ _assert_1                       │ call_function │ <function _assert at 0x7f5ad6f387c0>                   │ PatchEmbed            │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ patch_embed_proj                │ call_module   │ patch_embed.proj                                       │ Conv2d                │ 231211008      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ flatten                         │ call_method   │ flatten                                                │ PatchEmbed            │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ transpose                       │ call_method   │ transpose                                              │ PatchEmbed            │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ patch_embed_norm                │ call_module   │ patch_embed.norm                                       │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ pos_embed                       │ get_attr      │ pos_embed                                              │                       │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ cls_token                       │ get_attr      │ cls_token                                              │                       │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getattr_2                       │ call_function │ <built-in function getattr>                            │                       │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_4                       │ call_function │ <built-in function getitem>                            │                       │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ expand                          │ call_method   │ expand                                                 │                       │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ cat                             │ call_function │ <built-in method cat of type object at 0x7f5af9b15aa0> │                       │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ add                             │ call_function │ <built-in function add>                                │                       │ 151296         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ pos_drop                        │ call_module   │ pos_drop                                               │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ patch_drop                      │ call_module   │ patch_drop                                             │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ norm_pre                        │ call_module   │ norm_pre                                               │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_norm1                  │ call_module   │ blocks.0.norm1                                         │ LayerNorm             │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getattr_3                       │ call_function │ <built-in function getattr>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_5                       │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_6                       │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_7                       │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_attn_qkv               │ call_module   │ blocks.0.attn.qkv                                      │ Linear                │ 697171968      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ reshape                         │ call_method   │ reshape                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ permute                         │ call_method   │ permute                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ unbind                          │ call_method   │ unbind                                                 │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_8                       │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_9                       │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_10                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_attn_q_norm            │ call_module   │ blocks.0.attn.q_norm                                   │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_attn_k_norm            │ call_module   │ blocks.0.attn.k_norm                                   │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ scaled_dot_product_attention    │ call_function │ <built-in function scaled_dot_product_attention>       │ Attention             │ not_recognized │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ transpose_1                     │ call_method   │ transpose                                              │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ reshape_1                       │ call_method   │ reshape                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_attn_proj              │ call_module   │ blocks.0.attn.proj                                     │ Linear                │ 232390656      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_attn_proj_drop         │ call_module   │ blocks.0.attn.proj_drop                                │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_ls1                    │ call_module   │ blocks.0.ls1                                           │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_drop_path1             │ call_module   │ blocks.0.drop_path1                                    │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ add_1                           │ call_function │ <built-in function add>                                │ Block                 │ 151296         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_norm2                  │ call_module   │ blocks.0.norm2                                         │ LayerNorm             │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_mlp_fc1                │ call_module   │ blocks.0.mlp.fc1                                       │ Linear                │ 929562624      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_mlp_act                │ call_module   │ blocks.0.mlp.act                                       │ GELU                  │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_mlp_drop1              │ call_module   │ blocks.0.mlp.drop1                                     │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_mlp_norm               │ call_module   │ blocks.0.mlp.norm                                      │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_mlp_fc2                │ call_module   │ blocks.0.mlp.fc2                                       │ Linear                │ 929562624      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_mlp_drop2              │ call_module   │ blocks.0.mlp.drop2                                     │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_ls2                    │ call_module   │ blocks.0.ls2                                           │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_0_drop_path2             │ call_module   │ blocks.0.drop_path2                                    │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ add_2                           │ call_function │ <built-in function add>                                │ Block                 │ 151296         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_norm1                  │ call_module   │ blocks.1.norm1                                         │ LayerNorm             │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getattr_4                       │ call_function │ <built-in function getattr>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_11                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_12                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_13                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_attn_qkv               │ call_module   │ blocks.1.attn.qkv                                      │ Linear                │ 697171968      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ reshape_2                       │ call_method   │ reshape                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ permute_1                       │ call_method   │ permute                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ unbind_1                        │ call_method   │ unbind                                                 │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_14                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_15                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_16                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_attn_q_norm            │ call_module   │ blocks.1.attn.q_norm                                   │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_attn_k_norm            │ call_module   │ blocks.1.attn.k_norm                                   │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ scaled_dot_product_attention_1  │ call_function │ <built-in function scaled_dot_product_attention>       │ Attention             │ not_recognized │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ transpose_2                     │ call_method   │ transpose                                              │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ reshape_3                       │ call_method   │ reshape                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_attn_proj              │ call_module   │ blocks.1.attn.proj                                     │ Linear                │ 232390656      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_attn_proj_drop         │ call_module   │ blocks.1.attn.proj_drop                                │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_ls1                    │ call_module   │ blocks.1.ls1                                           │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_drop_path1             │ call_module   │ blocks.1.drop_path1                                    │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ add_3                           │ call_function │ <built-in function add>                                │ Block                 │ 151296         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_norm2                  │ call_module   │ blocks.1.norm2                                         │ LayerNorm             │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_mlp_fc1                │ call_module   │ blocks.1.mlp.fc1                                       │ Linear                │ 929562624      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_mlp_act                │ call_module   │ blocks.1.mlp.act                                       │ GELU                  │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_mlp_drop1              │ call_module   │ blocks.1.mlp.drop1                                     │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_mlp_norm               │ call_module   │ blocks.1.mlp.norm                                      │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_mlp_fc2                │ call_module   │ blocks.1.mlp.fc2                                       │ Linear                │ 929562624      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_mlp_drop2              │ call_module   │ blocks.1.mlp.drop2                                     │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_ls2                    │ call_module   │ blocks.1.ls2                                           │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_1_drop_path2             │ call_module   │ blocks.1.drop_path2                                    │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ add_4                           │ call_function │ <built-in function add>                                │ Block                 │ 151296         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_norm1                  │ call_module   │ blocks.2.norm1                                         │ LayerNorm             │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getattr_5                       │ call_function │ <built-in function getattr>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_17                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_18                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_19                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_attn_qkv               │ call_module   │ blocks.2.attn.qkv                                      │ Linear                │ 697171968      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ reshape_4                       │ call_method   │ reshape                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ permute_2                       │ call_method   │ permute                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ unbind_2                        │ call_method   │ unbind                                                 │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_20                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_21                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_22                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_attn_q_norm            │ call_module   │ blocks.2.attn.q_norm                                   │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_attn_k_norm            │ call_module   │ blocks.2.attn.k_norm                                   │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ scaled_dot_product_attention_2  │ call_function │ <built-in function scaled_dot_product_attention>       │ Attention             │ not_recognized │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ transpose_3                     │ call_method   │ transpose                                              │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ reshape_5                       │ call_method   │ reshape                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_attn_proj              │ call_module   │ blocks.2.attn.proj                                     │ Linear                │ 232390656      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_attn_proj_drop         │ call_module   │ blocks.2.attn.proj_drop                                │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_ls1                    │ call_module   │ blocks.2.ls1                                           │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_drop_path1             │ call_module   │ blocks.2.drop_path1                                    │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ add_5                           │ call_function │ <built-in function add>                                │ Block                 │ 151296         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_norm2                  │ call_module   │ blocks.2.norm2                                         │ LayerNorm             │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_mlp_fc1                │ call_module   │ blocks.2.mlp.fc1                                       │ Linear                │ 929562624      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_mlp_act                │ call_module   │ blocks.2.mlp.act                                       │ GELU                  │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_mlp_drop1              │ call_module   │ blocks.2.mlp.drop1                                     │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_mlp_norm               │ call_module   │ blocks.2.mlp.norm                                      │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_mlp_fc2                │ call_module   │ blocks.2.mlp.fc2                                       │ Linear                │ 929562624      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_mlp_drop2              │ call_module   │ blocks.2.mlp.drop2                                     │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_ls2                    │ call_module   │ blocks.2.ls2                                           │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_2_drop_path2             │ call_module   │ blocks.2.drop_path2                                    │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ add_6                           │ call_function │ <built-in function add>                                │ Block                 │ 151296         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_norm1                  │ call_module   │ blocks.3.norm1                                         │ LayerNorm             │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getattr_6                       │ call_function │ <built-in function getattr>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_23                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_24                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_25                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_attn_qkv               │ call_module   │ blocks.3.attn.qkv                                      │ Linear                │ 697171968      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ reshape_6                       │ call_method   │ reshape                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ permute_3                       │ call_method   │ permute                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ unbind_3                        │ call_method   │ unbind                                                 │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_26                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_27                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_28                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_attn_q_norm            │ call_module   │ blocks.3.attn.q_norm                                   │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_attn_k_norm            │ call_module   │ blocks.3.attn.k_norm                                   │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ scaled_dot_product_attention_3  │ call_function │ <built-in function scaled_dot_product_attention>       │ Attention             │ not_recognized │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ transpose_4                     │ call_method   │ transpose                                              │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ reshape_7                       │ call_method   │ reshape                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_attn_proj              │ call_module   │ blocks.3.attn.proj                                     │ Linear                │ 232390656      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_attn_proj_drop         │ call_module   │ blocks.3.attn.proj_drop                                │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_ls1                    │ call_module   │ blocks.3.ls1                                           │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_drop_path1             │ call_module   │ blocks.3.drop_path1                                    │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ add_7                           │ call_function │ <built-in function add>                                │ Block                 │ 151296         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_norm2                  │ call_module   │ blocks.3.norm2                                         │ LayerNorm             │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_mlp_fc1                │ call_module   │ blocks.3.mlp.fc1                                       │ Linear                │ 929562624      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_mlp_act                │ call_module   │ blocks.3.mlp.act                                       │ GELU                  │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_mlp_drop1              │ call_module   │ blocks.3.mlp.drop1                                     │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_mlp_norm               │ call_module   │ blocks.3.mlp.norm                                      │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_mlp_fc2                │ call_module   │ blocks.3.mlp.fc2                                       │ Linear                │ 929562624      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_mlp_drop2              │ call_module   │ blocks.3.mlp.drop2                                     │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_ls2                    │ call_module   │ blocks.3.ls2                                           │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_3_drop_path2             │ call_module   │ blocks.3.drop_path2                                    │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ add_8                           │ call_function │ <built-in function add>                                │ Block                 │ 151296         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_4_norm1                  │ call_module   │ blocks.4.norm1                                         │ LayerNorm             │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getattr_7                       │ call_function │ <built-in function getattr>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_29                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_30                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_31                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_4_attn_qkv               │ call_module   │ blocks.4.attn.qkv                                      │ Linear                │ 697171968      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ reshape_8                       │ call_method   │ reshape                                                │ Attention             │ 0              │
# ...
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_10_drop_path1            │ call_module   │ blocks.10.drop_path1                                   │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ add_21                          │ call_function │ <built-in function add>                                │ Block                 │ 151296         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_10_norm2                 │ call_module   │ blocks.10.norm2                                        │ LayerNorm             │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_10_mlp_fc1               │ call_module   │ blocks.10.mlp.fc1                                      │ Linear                │ 929562624      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_10_mlp_act               │ call_module   │ blocks.10.mlp.act                                      │ GELU                  │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_10_mlp_drop1             │ call_module   │ blocks.10.mlp.drop1                                    │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_10_mlp_norm              │ call_module   │ blocks.10.mlp.norm                                     │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_10_mlp_fc2               │ call_module   │ blocks.10.mlp.fc2                                      │ Linear                │ 929562624      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_10_mlp_drop2             │ call_module   │ blocks.10.mlp.drop2                                    │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_10_ls2                   │ call_module   │ blocks.10.ls2                                          │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_10_drop_path2            │ call_module   │ blocks.10.drop_path2                                   │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ add_22                          │ call_function │ <built-in function add>                                │ Block                 │ 151296         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_norm1                 │ call_module   │ blocks.11.norm1                                        │ LayerNorm             │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getattr_14                      │ call_function │ <built-in function getattr>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_71                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_72                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_73                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_attn_qkv              │ call_module   │ blocks.11.attn.qkv                                     │ Linear                │ 697171968      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ reshape_22                      │ call_method   │ reshape                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ permute_11                      │ call_method   │ permute                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ unbind_11                       │ call_method   │ unbind                                                 │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_74                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_75                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_76                      │ call_function │ <built-in function getitem>                            │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_attn_q_norm           │ call_module   │ blocks.11.attn.q_norm                                  │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_attn_k_norm           │ call_module   │ blocks.11.attn.k_norm                                  │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ scaled_dot_product_attention_11 │ call_function │ <built-in function scaled_dot_product_attention>       │ Attention             │ not_recognized │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ transpose_12                    │ call_method   │ transpose                                              │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ reshape_23                      │ call_method   │ reshape                                                │ Attention             │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_attn_proj             │ call_module   │ blocks.11.attn.proj                                    │ Linear                │ 232390656      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_attn_proj_drop        │ call_module   │ blocks.11.attn.proj_drop                               │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_ls1                   │ call_module   │ blocks.11.ls1                                          │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_drop_path1            │ call_module   │ blocks.11.drop_path1                                   │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ add_23                          │ call_function │ <built-in function add>                                │ Block                 │ 151296         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_norm2                 │ call_module   │ blocks.11.norm2                                        │ LayerNorm             │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_mlp_fc1               │ call_module   │ blocks.11.mlp.fc1                                      │ Linear                │ 929562624      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_mlp_act               │ call_module   │ blocks.11.mlp.act                                      │ GELU                  │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_mlp_drop1             │ call_module   │ blocks.11.mlp.drop1                                    │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_mlp_norm              │ call_module   │ blocks.11.mlp.norm                                     │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_mlp_fc2               │ call_module   │ blocks.11.mlp.fc2                                      │ Linear                │ 929562624      │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_mlp_drop2             │ call_module   │ blocks.11.mlp.drop2                                    │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_ls2                   │ call_module   │ blocks.11.ls2                                          │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ blocks_11_drop_path2            │ call_module   │ blocks.11.drop_path2                                   │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ add_24                          │ call_function │ <built-in function add>                                │ Block                 │ 151296         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ norm                            │ call_module   │ norm                                                   │ LayerNorm             │ 605184         │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ getitem_77                      │ call_function │ <built-in function getitem>                            │                       │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ fc_norm                         │ call_module   │ fc_norm                                                │ Identity              │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ head_drop                       │ call_module   │ head_drop                                              │ Dropout               │ 0              │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ head                            │ call_module   │ head                                                   │ Linear                │ 1536000        │
# ├─────────────────────────────────┼───────────────┼────────────────────────────────────────────────────────┼───────────────────────┼────────────────┤
# │ output                          │ output        │ output                                                 │                       │ 0              │
# ╘═════════════════════════════════╧═══════════════╧════════════════════════════════════════════════════════╧═══════════════════════╧════════════════╛
# total_flops = 33,723,175,682
# /media/pc/data/tmp/cache/conda/envs/py311/lib/python3.11/site-packages/torch/overrides.py:110: UserWarning: 'has_cuda' is deprecated, please use 'torch.backends.cuda.is_built()'
#   torch.has_cuda,
# /media/pc/data/tmp/cache/conda/envs/py311/lib/python3.11/site-packages/torch/overrides.py:111: UserWarning: 'has_cudnn' is deprecated, please use 'torch.backends.cudnn.is_available()'
#   torch.has_cudnn,
# /media/pc/data/tmp/cache/conda/envs/py311/lib/python3.11/site-packages/torch/overrides.py:117: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   torch.has_mps,
# /media/pc/data/tmp/cache/conda/envs/py311/lib/python3.11/site-packages/torch/overrides.py:118: UserWarning: 'has_mkldnn' is deprecated, please use 'torch.backends.mkldnn.is_available()'
#   torch.has_mkldnn,

# %%
gm = torch.fx.symbolic_trace(resnet)
sample_input = torch.randn([1, 3, 224, 224])
result_header = ['node_name', 'node_op', 'op_target', 'nn_module_stack[-1]', 'flops']
result_table = get_FLOPs(gm, sample_input)
__missing_values = [''] * 4 + ['ERROR']
# table_str = tabulate(result_table, result_header, tablefmt='rst', missingval=__missing_values)
table_str = tabulate(result_table, result_header, tablefmt='fancy_grid', missingval=__missing_values)
print(table_str)
valid_flops_list = list(filter(lambda _f: isinstance(_f, int), list(zip(*result_table))[-1]))
total_flops = sum(valid_flops_list)
num_empty_flops = len(result_table) - len(valid_flops_list)
print(f"total_flops = {total_flops:3,}")
# Out:
# ╒═══════════════════════╤═══════════════╤═════════════════════════╤═══════════════════════╤═══════════╕
# │ node_name             │ node_op       │ op_target               │ nn_module_stack[-1]   │     flops │
# ╞═══════════════════════╪═══════════════╪═════════════════════════╪═══════════════════════╪═══════════╡
# │ x                     │ placeholder   │ x                       │                       │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ conv1                 │ call_module   │ conv1                   │ Conv2d                │ 235225088 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ bn1                   │ call_module   │ bn1                     │ BatchNorm2d           │   3211264 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ act1                  │ call_module   │ act1                    │ ReLU                  │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ maxpool               │ call_module   │ maxpool                 │ MaxPool2d             │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_0_conv1        │ call_module   │ layer1.0.conv1          │ Conv2d                │  25489408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_0_bn1          │ call_module   │ layer1.0.bn1            │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_0_act1         │ call_module   │ layer1.0.act1           │ ReLU                  │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_0_conv2        │ call_module   │ layer1.0.conv2          │ Conv2d                │ 231010304 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_0_bn2          │ call_module   │ layer1.0.bn2            │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_0_drop_block   │ call_module   │ layer1.0.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_0_act2         │ call_module   │ layer1.0.act2           │ ReLU                  │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_0_aa           │ call_module   │ layer1.0.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_0_conv3        │ call_module   │ layer1.0.conv3          │ Conv2d                │ 101957632 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_0_bn3          │ call_module   │ layer1.0.bn3            │ BatchNorm2d           │   3211264 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_0_downsample_0 │ call_module   │ layer1.0.downsample.0   │ Conv2d                │ 101957632 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_0_downsample_1 │ call_module   │ layer1.0.downsample.1   │ BatchNorm2d           │   3211264 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add                   │ call_function │ <built-in function add> │ Bottleneck            │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_0_act3         │ call_module   │ layer1.0.act3           │ ReLU                  │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_1_conv1        │ call_module   │ layer1.1.conv1          │ Conv2d                │ 102559744 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_1_bn1          │ call_module   │ layer1.1.bn1            │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_1_act1         │ call_module   │ layer1.1.act1           │ ReLU                  │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_1_conv2        │ call_module   │ layer1.1.conv2          │ Conv2d                │ 231010304 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_1_bn2          │ call_module   │ layer1.1.bn2            │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_1_drop_block   │ call_module   │ layer1.1.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_1_act2         │ call_module   │ layer1.1.act2           │ ReLU                  │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_1_aa           │ call_module   │ layer1.1.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_1_conv3        │ call_module   │ layer1.1.conv3          │ Conv2d                │ 101957632 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_1_bn3          │ call_module   │ layer1.1.bn3            │ BatchNorm2d           │   3211264 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_1                 │ call_function │ <built-in function add> │ Bottleneck            │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_1_act3         │ call_module   │ layer1.1.act3           │ ReLU                  │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_2_conv1        │ call_module   │ layer1.2.conv1          │ Conv2d                │ 102559744 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_2_bn1          │ call_module   │ layer1.2.bn1            │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_2_act1         │ call_module   │ layer1.2.act1           │ ReLU                  │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_2_conv2        │ call_module   │ layer1.2.conv2          │ Conv2d                │ 231010304 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_2_bn2          │ call_module   │ layer1.2.bn2            │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_2_drop_block   │ call_module   │ layer1.2.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_2_act2         │ call_module   │ layer1.2.act2           │ ReLU                  │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_2_aa           │ call_module   │ layer1.2.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_2_conv3        │ call_module   │ layer1.2.conv3          │ Conv2d                │ 101957632 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_2_bn3          │ call_module   │ layer1.2.bn3            │ BatchNorm2d           │   3211264 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_2                 │ call_function │ <built-in function add> │ Bottleneck            │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer1_2_act3         │ call_module   │ layer1.2.act3           │ ReLU                  │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_0_conv1        │ call_module   │ layer2.0.conv1          │ Conv2d                │ 205119488 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_0_bn1          │ call_module   │ layer2.0.bn1            │ BatchNorm2d           │   1605632 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_0_act1         │ call_module   │ layer2.0.act1           │ ReLU                  │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_0_conv2        │ call_module   │ layer2.0.conv2          │ Conv2d                │ 231110656 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_0_bn2          │ call_module   │ layer2.0.bn2            │ BatchNorm2d           │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_0_drop_block   │ call_module   │ layer2.0.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_0_act2         │ call_module   │ layer2.0.act2           │ ReLU                  │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_0_aa           │ call_module   │ layer2.0.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_0_conv3        │ call_module   │ layer2.0.conv3          │ Conv2d                │ 102359040 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_0_bn3          │ call_module   │ layer2.0.bn3            │ BatchNorm2d           │   1605632 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_0_downsample_0 │ call_module   │ layer2.0.downsample.0   │ Conv2d                │ 205119488 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_0_downsample_1 │ call_module   │ layer2.0.downsample.1   │ BatchNorm2d           │   1605632 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_3                 │ call_function │ <built-in function add> │ Bottleneck            │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_0_act3         │ call_module   │ layer2.0.act3           │ ReLU                  │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_1_conv1        │ call_module   │ layer2.1.conv1          │ Conv2d                │ 102660096 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_1_bn1          │ call_module   │ layer2.1.bn1            │ BatchNorm2d           │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_1_act1         │ call_module   │ layer2.1.act1           │ ReLU                  │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_1_conv2        │ call_module   │ layer2.1.conv2          │ Conv2d                │ 231110656 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_1_bn2          │ call_module   │ layer2.1.bn2            │ BatchNorm2d           │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_1_drop_block   │ call_module   │ layer2.1.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_1_act2         │ call_module   │ layer2.1.act2           │ ReLU                  │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_1_aa           │ call_module   │ layer2.1.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_1_conv3        │ call_module   │ layer2.1.conv3          │ Conv2d                │ 102359040 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_1_bn3          │ call_module   │ layer2.1.bn3            │ BatchNorm2d           │   1605632 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_4                 │ call_function │ <built-in function add> │ Bottleneck            │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_1_act3         │ call_module   │ layer2.1.act3           │ ReLU                  │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_2_conv1        │ call_module   │ layer2.2.conv1          │ Conv2d                │ 102660096 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_2_bn1          │ call_module   │ layer2.2.bn1            │ BatchNorm2d           │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_2_act1         │ call_module   │ layer2.2.act1           │ ReLU                  │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_2_conv2        │ call_module   │ layer2.2.conv2          │ Conv2d                │ 231110656 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_2_bn2          │ call_module   │ layer2.2.bn2            │ BatchNorm2d           │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_2_drop_block   │ call_module   │ layer2.2.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_2_act2         │ call_module   │ layer2.2.act2           │ ReLU                  │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_2_aa           │ call_module   │ layer2.2.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_2_conv3        │ call_module   │ layer2.2.conv3          │ Conv2d                │ 102359040 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_2_bn3          │ call_module   │ layer2.2.bn3            │ BatchNorm2d           │   1605632 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_5                 │ call_function │ <built-in function add> │ Bottleneck            │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_2_act3         │ call_module   │ layer2.2.act3           │ ReLU                  │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_3_conv1        │ call_module   │ layer2.3.conv1          │ Conv2d                │ 102660096 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_3_bn1          │ call_module   │ layer2.3.bn1            │ BatchNorm2d           │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_3_act1         │ call_module   │ layer2.3.act1           │ ReLU                  │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_3_conv2        │ call_module   │ layer2.3.conv2          │ Conv2d                │ 231110656 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_3_bn2          │ call_module   │ layer2.3.bn2            │ BatchNorm2d           │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_3_drop_block   │ call_module   │ layer2.3.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_3_act2         │ call_module   │ layer2.3.act2           │ ReLU                  │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_3_aa           │ call_module   │ layer2.3.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_3_conv3        │ call_module   │ layer2.3.conv3          │ Conv2d                │ 102359040 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_3_bn3          │ call_module   │ layer2.3.bn3            │ BatchNorm2d           │   1605632 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_6                 │ call_function │ <built-in function add> │ Bottleneck            │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer2_3_act3         │ call_module   │ layer2.3.act3           │ ReLU                  │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_0_conv1        │ call_module   │ layer3.0.conv1          │ Conv2d                │ 205320192 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_0_bn1          │ call_module   │ layer3.0.bn1            │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_0_act1         │ call_module   │ layer3.0.act1           │ ReLU                  │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_0_conv2        │ call_module   │ layer3.0.conv2          │ Conv2d                │ 231160832 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_0_bn2          │ call_module   │ layer3.0.bn2            │ BatchNorm2d           │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_0_drop_block   │ call_module   │ layer3.0.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_0_act2         │ call_module   │ layer3.0.act2           │ ReLU                  │     50176 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_0_aa           │ call_module   │ layer3.0.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_0_conv3        │ call_module   │ layer3.0.conv3          │ Conv2d                │ 102559744 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_0_bn3          │ call_module   │ layer3.0.bn3            │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_0_downsample_0 │ call_module   │ layer3.0.downsample.0   │ Conv2d                │ 205320192 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_0_downsample_1 │ call_module   │ layer3.0.downsample.1   │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_7                 │ call_function │ <built-in function add> │ Bottleneck            │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_0_act3         │ call_module   │ layer3.0.act3           │ ReLU                  │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_1_conv1        │ call_module   │ layer3.1.conv1          │ Conv2d                │ 102710272 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_1_bn1          │ call_module   │ layer3.1.bn1            │ BatchNorm2d           │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_1_act1         │ call_module   │ layer3.1.act1           │ ReLU                  │     50176 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_1_conv2        │ call_module   │ layer3.1.conv2          │ Conv2d                │ 231160832 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_1_bn2          │ call_module   │ layer3.1.bn2            │ BatchNorm2d           │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_1_drop_block   │ call_module   │ layer3.1.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_1_act2         │ call_module   │ layer3.1.act2           │ ReLU                  │     50176 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_1_aa           │ call_module   │ layer3.1.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_1_conv3        │ call_module   │ layer3.1.conv3          │ Conv2d                │ 102559744 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_1_bn3          │ call_module   │ layer3.1.bn3            │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_8                 │ call_function │ <built-in function add> │ Bottleneck            │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_1_act3         │ call_module   │ layer3.1.act3           │ ReLU                  │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_2_conv1        │ call_module   │ layer3.2.conv1          │ Conv2d                │ 102710272 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_2_bn1          │ call_module   │ layer3.2.bn1            │ BatchNorm2d           │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_2_act1         │ call_module   │ layer3.2.act1           │ ReLU                  │     50176 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_2_conv2        │ call_module   │ layer3.2.conv2          │ Conv2d                │ 231160832 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_2_bn2          │ call_module   │ layer3.2.bn2            │ BatchNorm2d           │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_2_drop_block   │ call_module   │ layer3.2.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_2_act2         │ call_module   │ layer3.2.act2           │ ReLU                  │     50176 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_2_aa           │ call_module   │ layer3.2.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_2_conv3        │ call_module   │ layer3.2.conv3          │ Conv2d                │ 102559744 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_2_bn3          │ call_module   │ layer3.2.bn3            │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_9                 │ call_function │ <built-in function add> │ Bottleneck            │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_2_act3         │ call_module   │ layer3.2.act3           │ ReLU                  │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_3_conv1        │ call_module   │ layer3.3.conv1          │ Conv2d                │ 102710272 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_3_bn1          │ call_module   │ layer3.3.bn1            │ BatchNorm2d           │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_3_act1         │ call_module   │ layer3.3.act1           │ ReLU                  │     50176 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_3_conv2        │ call_module   │ layer3.3.conv2          │ Conv2d                │ 231160832 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_3_bn2          │ call_module   │ layer3.3.bn2            │ BatchNorm2d           │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_3_drop_block   │ call_module   │ layer3.3.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_3_act2         │ call_module   │ layer3.3.act2           │ ReLU                  │     50176 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_3_aa           │ call_module   │ layer3.3.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_3_conv3        │ call_module   │ layer3.3.conv3          │ Conv2d                │ 102559744 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_3_bn3          │ call_module   │ layer3.3.bn3            │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_10                │ call_function │ <built-in function add> │ Bottleneck            │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_3_act3         │ call_module   │ layer3.3.act3           │ ReLU                  │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_4_conv1        │ call_module   │ layer3.4.conv1          │ Conv2d                │ 102710272 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_4_bn1          │ call_module   │ layer3.4.bn1            │ BatchNorm2d           │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_4_act1         │ call_module   │ layer3.4.act1           │ ReLU                  │     50176 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_4_conv2        │ call_module   │ layer3.4.conv2          │ Conv2d                │ 231160832 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_4_bn2          │ call_module   │ layer3.4.bn2            │ BatchNorm2d           │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_4_drop_block   │ call_module   │ layer3.4.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_4_act2         │ call_module   │ layer3.4.act2           │ ReLU                  │     50176 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_4_aa           │ call_module   │ layer3.4.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_4_conv3        │ call_module   │ layer3.4.conv3          │ Conv2d                │ 102559744 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_4_bn3          │ call_module   │ layer3.4.bn3            │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_11                │ call_function │ <built-in function add> │ Bottleneck            │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_4_act3         │ call_module   │ layer3.4.act3           │ ReLU                  │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_5_conv1        │ call_module   │ layer3.5.conv1          │ Conv2d                │ 102710272 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_5_bn1          │ call_module   │ layer3.5.bn1            │ BatchNorm2d           │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_5_act1         │ call_module   │ layer3.5.act1           │ ReLU                  │     50176 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_5_conv2        │ call_module   │ layer3.5.conv2          │ Conv2d                │ 231160832 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_5_bn2          │ call_module   │ layer3.5.bn2            │ BatchNorm2d           │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_5_drop_block   │ call_module   │ layer3.5.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_5_act2         │ call_module   │ layer3.5.act2           │ ReLU                  │     50176 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_5_aa           │ call_module   │ layer3.5.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_5_conv3        │ call_module   │ layer3.5.conv3          │ Conv2d                │ 102559744 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_5_bn3          │ call_module   │ layer3.5.bn3            │ BatchNorm2d           │    802816 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_12                │ call_function │ <built-in function add> │ Bottleneck            │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer3_5_act3         │ call_module   │ layer3.5.act3           │ ReLU                  │    200704 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_0_conv1        │ call_module   │ layer4.0.conv1          │ Conv2d                │ 205420544 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_0_bn1          │ call_module   │ layer4.0.bn1            │ BatchNorm2d           │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_0_act1         │ call_module   │ layer4.0.act1           │ ReLU                  │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_0_conv2        │ call_module   │ layer4.0.conv2          │ Conv2d                │ 231185920 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_0_bn2          │ call_module   │ layer4.0.bn2            │ BatchNorm2d           │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_0_drop_block   │ call_module   │ layer4.0.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_0_act2         │ call_module   │ layer4.0.act2           │ ReLU                  │     25088 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_0_aa           │ call_module   │ layer4.0.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_0_conv3        │ call_module   │ layer4.0.conv3          │ Conv2d                │ 102660096 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_0_bn3          │ call_module   │ layer4.0.bn3            │ BatchNorm2d           │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_0_downsample_0 │ call_module   │ layer4.0.downsample.0   │ Conv2d                │ 205420544 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_0_downsample_1 │ call_module   │ layer4.0.downsample.1   │ BatchNorm2d           │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_13                │ call_function │ <built-in function add> │ Bottleneck            │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_0_act3         │ call_module   │ layer4.0.act3           │ ReLU                  │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_1_conv1        │ call_module   │ layer4.1.conv1          │ Conv2d                │ 102735360 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_1_bn1          │ call_module   │ layer4.1.bn1            │ BatchNorm2d           │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_1_act1         │ call_module   │ layer4.1.act1           │ ReLU                  │     25088 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_1_conv2        │ call_module   │ layer4.1.conv2          │ Conv2d                │ 231185920 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_1_bn2          │ call_module   │ layer4.1.bn2            │ BatchNorm2d           │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_1_drop_block   │ call_module   │ layer4.1.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_1_act2         │ call_module   │ layer4.1.act2           │ ReLU                  │     25088 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_1_aa           │ call_module   │ layer4.1.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_1_conv3        │ call_module   │ layer4.1.conv3          │ Conv2d                │ 102660096 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_1_bn3          │ call_module   │ layer4.1.bn3            │ BatchNorm2d           │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_14                │ call_function │ <built-in function add> │ Bottleneck            │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_1_act3         │ call_module   │ layer4.1.act3           │ ReLU                  │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_2_conv1        │ call_module   │ layer4.2.conv1          │ Conv2d                │ 102735360 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_2_bn1          │ call_module   │ layer4.2.bn1            │ BatchNorm2d           │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_2_act1         │ call_module   │ layer4.2.act1           │ ReLU                  │     25088 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_2_conv2        │ call_module   │ layer4.2.conv2          │ Conv2d                │ 231185920 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_2_bn2          │ call_module   │ layer4.2.bn2            │ BatchNorm2d           │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_2_drop_block   │ call_module   │ layer4.2.drop_block     │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_2_act2         │ call_module   │ layer4.2.act2           │ ReLU                  │     25088 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_2_aa           │ call_module   │ layer4.2.aa             │ Identity              │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_2_conv3        │ call_module   │ layer4.2.conv3          │ Conv2d                │ 102660096 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_2_bn3          │ call_module   │ layer4.2.bn3            │ BatchNorm2d           │    401408 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ add_15                │ call_function │ <built-in function add> │ Bottleneck            │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ layer4_2_act3         │ call_module   │ layer4.2.act3           │ ReLU                  │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ global_pool_pool      │ call_module   │ global_pool.pool        │ AdaptiveAvgPool2d     │    100352 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ global_pool_flatten   │ call_module   │ global_pool.flatten     │ Flatten               │         0 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ fc                    │ call_module   │ fc                      │ Linear                │   4096000 │
# ├───────────────────────┼───────────────┼─────────────────────────┼───────────────────────┼───────────┤
# │ output                │ output        │ output                  │                       │         0 │
# ╘═══════════════════════╧═══════════════╧═════════════════════════╧═══════════════════════╧═══════════╛
# total_flops = 8,227,340,288

# %%
import torch
from torch import Tensor
import torch.nn as nn
import torch.nn.functional as F
from torch.jit import Final
from timm.layers import use_fused_attn, Mlp, DropPath


class Attention(nn.Module):
    '''
    REF: https://github.com/huggingface/pytorch-image-models/blob/main/timm/models/vision_transformer.py
    '''
    fused_attn: Final[bool]

    def __init__(
            self,
            dim,
            num_heads=8,
            qkv_bias=False,
            qk_norm=False,
            attn_drop=0.,
            proj_drop=0.,
            norm_layer=nn.LayerNorm,
    ):
        super().__init__()
        assert dim % num_heads == 0, 'dim should be divisible by num_heads'
        self.num_heads = num_heads
        self.head_dim = dim // num_heads
        self.scale = self.head_dim ** -0.5
        self.fused_attn = use_fused_attn()

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.q_norm = norm_layer(self.head_dim) if qk_norm else nn.Identity()
        self.k_norm = norm_layer(self.head_dim) if qk_norm else nn.Identity()
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

    @torch.no_grad()
    def forward(self, x):
        B, N, C = x.shape
        qkv = self.qkv(x).reshape(B, N, 3, self.num_heads, self.head_dim).permute(2, 0, 3, 1, 4)
        q, k, v = qkv.unbind(0)
        q, k = self.q_norm(q), self.k_norm(k)

        if self.fused_attn:
            x = F.scaled_dot_product_attention(
                q, k, v,
                dropout_p=self.attn_drop.p,
            )
        else:
            q = q * self.scale
            attn = q @ k.transpose(-2, -1)
            attn = attn.softmax(dim=-1)
            attn = self.attn_drop(attn)
            x = attn @ v

        x = x.transpose(1, 2).reshape(B, N, C)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x


class LayerScale(nn.Module):
    def __init__(self, dim, init_values=1e-5, inplace=False):
        super().__init__()
        self.inplace = inplace
        self.gamma = nn.Parameter(init_values * torch.ones(dim))

    def forward(self, x):
        return x.mul_(self.gamma) if self.inplace else x * self.gamma


class Block(nn.Module):
    def __init__(
            self,
            dim,
            num_heads,
            mlp_ratio=4.,
            qkv_bias=False,
            qk_norm=False,
            proj_drop=0.,
            attn_drop=0.,
            init_values=None,
            drop_path=0.,
            act_layer=nn.GELU,
            norm_layer=nn.LayerNorm,
            mlp_layer=Mlp,
    ):
        super().__init__()
        self.norm1 = norm_layer(dim)
        self.attn = Attention(
            dim,
            num_heads=num_heads,
            qkv_bias=qkv_bias,
            qk_norm=qk_norm,
            attn_drop=attn_drop,
            proj_drop=proj_drop,
            norm_layer=norm_layer,
        )
        self.ls1 = LayerScale(dim, init_values=init_values) if init_values else nn.Identity()
        self.drop_path1 = DropPath(drop_path) if drop_path > 0. else nn.Identity()

        self.norm2 = norm_layer(dim)
        self.mlp = mlp_layer(
            in_features=dim,
            hidden_features=int(dim * mlp_ratio),
            act_layer=act_layer,
            drop=proj_drop,
        )
        self.ls2 = LayerScale(dim, init_values=init_values) if init_values else nn.Identity()
        self.drop_path2 = DropPath(drop_path) if drop_path > 0. else nn.Identity()

    @torch.no_grad()
    def forward(self, x):
        x = x + self.drop_path1(self.ls1(self.attn(self.norm1(x))))
        x = x + self.drop_path2(self.ls2(self.mlp(self.norm2(x))))
        return x

# %%
C = 768

# Define the model: an attention block (refer to "timm": https://github.com/huggingface/pytorch-image-models/blob/main/timm/models/vision_transformer.py)
block = Block(C, num_heads=2, qkv_bias=True)
block.attn.fused_attn = False
block.eval()
model = block

# Input
# N: number of tokens
N = 14**2 + 1
B = 1

gm = torch.fx.symbolic_trace(model)
sample_input = torch.randn([B, N, C])
result_header = ['node_name', 'node_op', 'op_target', 'nn_module_stack[-1]', 'flops']
result_table = get_FLOPs(gm, sample_input)
__missing_values = [''] * 4 + ['ERROR']
# table_str = tabulate(result_table, result_header, tablefmt='rst', missingval=__missing_values)
table_str = tabulate(result_table, result_header, tablefmt='fancy_grid', missingval=__missing_values)
print(table_str)
valid_flops_list = list(filter(lambda _f: isinstance(_f, int), list(zip(*result_table))[-1]))
total_flops = sum(valid_flops_list)
num_empty_flops = len(result_table) - len(valid_flops_list)
print(f"total_flops = {total_flops:3,}")
# Out:
# ╒════════════════╤═══════════════╤═════════════════════════════╤═══════════════════════╤═══════════╕
# │ node_name      │ node_op       │ op_target                   │ nn_module_stack[-1]   │     flops │
# ╞════════════════╪═══════════════╪═════════════════════════════╪═══════════════════════╪═══════════╡
# │ x              │ placeholder   │ x                           │                       │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ norm1          │ call_module   │ norm1                       │ LayerNorm             │    605184 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ getattr_1      │ call_function │ <built-in function getattr> │ Attention             │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ getitem        │ call_function │ <built-in function getitem> │ Attention             │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ getitem_1      │ call_function │ <built-in function getitem> │ Attention             │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ getitem_2      │ call_function │ <built-in function getitem> │ Attention             │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ attn_qkv       │ call_module   │ attn.qkv                    │ Linear                │ 697171968 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ reshape        │ call_method   │ reshape                     │ Attention             │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ permute        │ call_method   │ permute                     │ Attention             │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ unbind         │ call_method   │ unbind                      │ Attention             │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ getitem_3      │ call_function │ <built-in function getitem> │ Attention             │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ getitem_4      │ call_function │ <built-in function getitem> │ Attention             │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ getitem_5      │ call_function │ <built-in function getitem> │ Attention             │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ attn_q_norm    │ call_module   │ attn.q_norm                 │ Identity              │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ attn_k_norm    │ call_module   │ attn.k_norm                 │ Identity              │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ mul            │ call_function │ <built-in function mul>     │ Attention             │    151296 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ transpose      │ call_method   │ transpose                   │ Attention             │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ matmul         │ call_function │ <built-in function matmul>  │ Attention             │  59533006 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ softmax        │ call_method   │ softmax                     │ Attention             │    232460 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ attn_attn_drop │ call_module   │ attn.attn_drop              │ Dropout               │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ matmul_1       │ call_function │ <built-in function matmul>  │ Attention             │  59459328 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ transpose_1    │ call_method   │ transpose                   │ Attention             │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ reshape_1      │ call_method   │ reshape                     │ Attention             │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ attn_proj      │ call_module   │ attn.proj                   │ Linear                │ 232390656 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ attn_proj_drop │ call_module   │ attn.proj_drop              │ Dropout               │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ ls1            │ call_module   │ ls1                         │ Identity              │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ drop_path1     │ call_module   │ drop_path1                  │ Identity              │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ add            │ call_function │ <built-in function add>     │                       │    151296 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ norm2          │ call_module   │ norm2                       │ LayerNorm             │    605184 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ mlp_fc1        │ call_module   │ mlp.fc1                     │ Linear                │ 929562624 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ mlp_act        │ call_module   │ mlp.act                     │ GELU                  │    605184 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ mlp_drop1      │ call_module   │ mlp.drop1                   │ Dropout               │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ mlp_norm       │ call_module   │ mlp.norm                    │ Identity              │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ mlp_fc2        │ call_module   │ mlp.fc2                     │ Linear                │ 929562624 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ mlp_drop2      │ call_module   │ mlp.drop2                   │ Dropout               │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ ls2            │ call_module   │ ls2                         │ Identity              │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ drop_path2     │ call_module   │ drop_path2                  │ Identity              │         0 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ add_1          │ call_function │ <built-in function add>     │                       │    151296 │
# ├────────────────┼───────────────┼─────────────────────────────┼───────────────────────┼───────────┤
# │ output         │ output        │ output                      │                       │         0 │
# ╘════════════════╧═══════════════╧═════════════════════════════╧═══════════════════════╧═══════════╛
# total_flops = 2,910,182,106
